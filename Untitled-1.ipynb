# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1, 2, 3, 4, 5])
b = np.array([2, 3, 4, 5, 6])
plt.scatter(a, b)
plt.xlabel('a')
plt.ylabel('b')
plt.title('Scatter Plot')
plt.show()
